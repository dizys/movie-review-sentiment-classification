# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# # Plan B: AWD_LSTM Transfer Learning with FastAI

# %%
from pathlib import Path

from fastai import *
from fastai.basic_data import *
from fastai.text import *
from torch import *
import pandas as pd

# %% [markdown]
# ## Preparing the data
#
# Use panda to conveniently import three `TSV` data files as `DataFrame`s.

# %%
path =  Path('data')

# %%
training_df = pd.read_table(path / 'training_set.ss')
test_df = pd.read_table(path / 'test_set.ss')
validation_df = pd.read_table(path / 'validation_set.ss')

# %% [markdown]
# `review_content` would be the only feature column, `rating` would be our target column

# %%
validation_df
# Out:
#           user_id  product_id  rating  \
# 0      ur0116181/  \tt0430357       6
# 1      ur0116181/  \tt0141941      10
# 2      ur0550732/  \tt0829459       9
# 3      ur0550732/  \tt0964517      10
# 4      ur0550732/  \tt0266543      10
# 5      ur0550732/  \tt0183649       8
# 6      ur0365713/  \tt0165854       6
# 7      ur0365713/  \tt0140352       8
# 8      ur0365713/  \tt0245674       7
# 9      ur0365713/  \tt0118636       6
# 10     ur0365713/  \tt0098084       6
# 11     ur0365713/  \tt0122143       7
# 12     ur0365713/  \tt0068646       8
# 13     ur0365713/  \tt0128278       8
# 14     ur0365713/  \tt0241303       9
# 15     ur0365713/  \tt0120601       6
# 16     ur2444068/  \tt0102768       8
# 17     ur2444068/  \tt0097737       3
# 18     ur2444068/  \tt1046163       3
# 19     ur2444068/  \tt1152836       8
# 20     ur2444068/  \tt0962736       8
# 21     ur2444068/  \tt0955308       8
# 22     ur2444068/  \tt0053172      10
# 23     ur2444068/  \tt1358168       8
# 24     ur2444068/  \tt0113481       6
# 25     ur2444068/  \tt0458352       7
# 26     ur2444068/  \tt1090687       9
# 27     ur2444068/  \tt1389137       7
# 28     ur2444068/  \tt0821640       7
# 29     ur2444068/  \tt1667353       8
# ...           ...         ...     ...
# 2064   ur0812631/  \tt0259711       5
# 2065   ur0812631/  \tt0201708       8
# 2066   ur0812631/  \tt0230697       7
# 2067  ur37581915/  \tt0110265       7
# 2068  ur37581915/  \tt0821640       5
# 2069  ur37581915/  \tt1656190       6
# 2070  ur37581915/  \tt1160368       6
# 2071  ur37581915/  \tt0068646       7
# 2072   ur6499406/  \tt1937396       5
# 2073   ur6499406/  \tt1568346       9
# 2074   ur0386241/  \tt0116421       5
# 2075   ur0386241/  \tt0256525       5
# 2076   ur0386241/  \tt0068612       6
# 2077   ur0386241/  \tt0093075       5
# 2078   ur0386241/  \tt0107953       4
# 2079   ur0386241/  \tt0076590       7
# 2080   ur0386241/  \tt0086320       5
# 2081   ur0386241/  \tt0119099       6
# 2082   ur0386241/  \tt0058329       5
# 2083   ur0386241/  \tt0066995       4
# 2084   ur0386241/  \tt0108162       6
# 2085   ur0386241/  \tt0083550       3
# 2086   ur0386241/  \tt0092857       5
# 2087   ur0386241/  \tt0075462       4
# 2088   ur0386241/  \tt0076630       7
# 2089   ur0386241/  \tt0029811       6
# 2090   ur0386241/  \tt0115964       4
# 2091   ur0194347/  \tt0084777       6
# 2092   ur0194347/  \tt0165710       4
# 2093   ur0194347/  \tt0186151       6
#
#                                          review_content
# 0     i 'm a huge fan of michael mann -lrb- i even l...
# 1     this film is unavoidably being compared to dir...
# 2     we start all of our reviews with the following...
# 3     my wife and i see over 100 movies a year , hav...
# 4     we see over 75 movies a year and have not rate...
# 5     we absolutely think that colin is simply a ter...
# 6     watching this film i feel like apologising to ...
# 7     russell crowe is fast gaining a great reputati...
# 8     i was expecting the usual teen slasher type ho...
# 9     apt pupil had the potential to be a great movi...
# 10    i found it really hard to come up with a mark ...
# 11    at the start of this film the first thing we s...
# 12    there is not a lot that can be said about the ...
# 13    anthony hopkins and cuba gooding jnr star in a...
# 14    having watched chocolat i so wanted to have a ...
# 15    if you have n't seen being john malkovich and ...
# 16    henry -lrb- harrison ford -rrb- is a terrific ...
# 17    steven -lrb- peter weller -rrb- is one of the ...
# 18    tank -lrb- dane cook -rrb- has a job as a `` '...
# 19    john dillinger -lrb- johnny depp -rrb- is very...
# 20    princess victoria -lrb- emily blunt -rrb- is i...
# 21    robin longstride -lrb- russell crowe -rrb- and...
# 22    jan morrow -lrb- doris day -rrb- , an interior...
# 23    a young man sits in an apartment , listening t...
# 24    johnny -lrb- keanu reeves -rrb- lives in 2021 ...
# 25    miranda -lrb- meryl streep -rrb- is at the hel...
# 26    steve lopez -lrb- robert , jr. -rrb- is an ace...
# 27    benjamin -lrb- matt damon -rrb- has recently b...
# 28    connor mead -lrb- matthew mcconaughey -rrb- is...
# 29    once upon a time , as you probably have heard ...
# ...                                                 ...
# 2064  this remake of open your eyes is mostly a poin...
# 2065  kiki 's delivery service is not an epic like o...
# 2066  this film is the film that started the whole a...
# 2067  killing zoe i liked it ... but it was a film o...
# 2068  ghosts of girlfriends past i am not a huge rom...
# 2069  safe . <sssss> i watched this movie with a fri...
# 2070  12 rounds this was a good action thriller . <s...
# 2071  the godfather a long time ago i started to wat...
# 2072  there is nothing to beat the aardmans ' animat...
# 2073  having waited before committing to try out thi...
# 2074  steven seagal certainly knows how to fight , a...
# 2075  `` the curse of the jade scorpion '' offers a ...
# 2076  provocative cartoon feature that was probably ...
# 2077  `` the gate '' is an ok little horror film . <...
# 2078  `` return of the living dead 3 '' is a sickeni...
# 2079  david cronenberg is perhaps a director incapab...
# 2080  the characters are idiotic , the acting is pre...
# 2081  `` fallen '' is an annoyingly derivative pictu...
# 2082  some people consider `` marnie '' to be hitchc...
# 2083  `` diamonds are forever '' is my personal cand...
# 2084  `` sliver '' was not nearly as bad as most rev...
# 2085  extraordinarily stupid -lrb- why does n't the ...
# 2086  can a single man wipe out all the drug lords a...
# 2087  this film had the potential to be a chilling h...
# 2088  the predicament of five doctors targeted by an...
# 2089  `` young and innocent '' is a passable but une...
# 2090  it 's certainly a well-shot film , and the cin...
# 2091  this has everything you 'd expect in an argent...
# 2092  detroit rock city -lrb- 1999 -rrb- * * four ki...
# 2093  frequency * * 1/2 the further behind you leave...
#
# [2094 rows x 4 columns]

# %% [markdown]
# ## Tokenization && Numericalization
#
# In fastai, `TextDataBunch` helps us to tokenize words and clean some parts of our texts like HTML code for instance.
#
# Also, once we have extracted tokens from our texts, DataBunch also helps to convert tokens to integers by creating a list of all the words used. By default,it only keeps the ones that appear at least twice with a maximum vocabulary size of 60,000 (by default) and replace the ones that don't make the cut by the unknown token `UNK`.

# %%
# Language model data
data_lm = TextLMDataBunch.from_df(path, training_df, valid_df=validation_df, test_df=test_df, text_cols=['review_content'], label_cols=['rating'])
# Classifier model data
data_clas = TextClasDataBunch.from_df(path, train_df=training_df, valid_df=validation_df, test_df=test_df, vocab=data_lm.train_ds.vocab, text_cols=['review_content'], label_cols=['rating'], bs=32)

# %%
data_lm.save('data_lm_export.pkl')
data_clas.save('data_clas_export.pkl')

# %%
data_lm = load_data(path, 'data_lm_export.pkl')
data_clas = load_data(path, 'data_clas_export.pkl', bs=16)

# %% [markdown]
# ## Language model
#
# Language model is trained to guess what the next word is, its input being all the previous words. It has a recurrent structure and a hidden state that is updated each time it sees a new word. This hidden state thus contains information about the sentence up to that point.
#
# We are going to use that 'knowledge' of the English language to build our classifier
#
# We use pretrained `AWD_LSTM` model as a starting point. `AWD-LSTM` has been dominating the state-of-the-art language modeling. All the top research papers on word-level models incorporate `AWD-LSTM`s.

# %% [markdown]
# ### LSTM
#
# A normal LSTM cell's mathematical formulation looks like this:
#
# $$i_t  = σ(W^ix_t + U^ih_{t-1})$$
# $$f_t = σ(W^fx_t  + U^fh_{t-1})$$
# $$o_t = σ(W^ox_t  + U^oh_{t-1})$$
# $$c'_t = tanh(W^cx_t  + U^ch_{t-1})$$
# $$c_t = i_t ⊙ c'_t + f_t ⊙ c'_{t-1}$$
# $$ht = o_t ⊙ tanh(c_t)$$
#
# where, $W^i$, $W^f$, $W^o$, $W^c$, $U^i$, $U^f$, $U^o$, $U^c$ are weight matrices, $x_t$ is the vector input to timestep $t$, $h_t$ is the current exposed hidden state, ct is the memory cell state, and $⊙$ is element-wise multiplication.
#
# ### AWD_LSTM: ASGD Weight-dropped LSTM
#
# The recurrent connections of an RNN have been prone to overfitting. Dropouts have been massively successful in feed-forward and convolutional neural networks to prevent overfitting. But applying dropouts similarly to an RNN's hidden state is ineffective as it disrupts the RNN's ability to retain long-term dependencies.
#
# To counter this problem, AWD_LSTM uses DropConnect. We know that in Dropout, a randomly selected subset of activations is set to zero within each layer. In DropConnect, instead of activations, a randomly selected subset of weights within the network is set to zero. Each unit thus receives input from a random subset of units in the previous layer.
#
# ![drop_connect](./images/drop_connect.jpg)
#
# DropConnect is applied on the hidden to hidden weight matrices ($U^i$, $U^f$, $U^o$, $U^c$) instead of the hidden or memory states. Since this dropout operation is performed once, before the forward and backward pass the impact on training speed is minimal and any standard optimized black box RNN implementation can be used. By performing dropout on the hidden-to-hidden weight matrices, overfitting can be prevented on the recurrent connections of the LSTM.
#
# [Details](https://yashuseth.blog/2018/09/12/awd-lstm-explanation-understanding-language-model/)

# %% [markdown]
# ### Train

# %%
learn = language_model_learner(data_lm, AWD_LSTM, drop_mult=0.5)

# %%
learn.fit_one_cycle(1, 1e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.753421</td>
#       <td>3.642199</td>
#       <td>0.386658</td>
#       <td>14:48</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Fine-tuning
#
# I would say `1e-2` or `1e-3` here as learning rate are like rule of numbs than magic numbers, which work most of the time.

# %%
# We unfreeze the entire model weights and start training 1 epoch
learn.unfreeze()
learn.fit_one_cycle(1, 1e-3)

# %%
learn.save_encoder('ft_enc') # 191.318M

# %%
# Have fun testing
learn.predict('find', n_words=10)
# Out:
# 'find although a true classic film for me for sense of'

# %% [markdown]
# ## Text Classifier
#
# So now we got a language model, then we need to build a classifier which will take in text and tell us the rating it guesses.
# For this specific task, fastai equips us with `text_classifier_learner`. Again, we start with pretrained `AWD_LSTM` network.

# %%
learn = text_classifier_learner(data_clas, AWD_LSTM, drop_mult=0.5)
# Load the language model we just trained as encoder
learn.load_encoder('ft_enc')

# %%
# See how the dataset looks
data_clas.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#       <th>target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>xxbos the day after tomorrow is one of those movies that comes along occasionally that operates on such a massive scale that it 's sure to be a success even if for no other reason than because it takes place in such a massive setting . &lt; xxrep 5 s &gt; i think that a large part of the appeal of disaster movies comes from the possibility of seeing somewhere</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <td>xxbos this is yet another summer blockbuster gone hollywood awry by being a bloated , self - indulging `` more is better '' behemoth . &lt; xxrep 5 s &gt; the series is based on my favorite disney amusement park ride of the same name . &lt; xxrep 5 s &gt; by this point i was surprised that the end product has been this tolerable , considering the sword of</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <td>xxbos `` talladega nights : the ballad of ricky bobby '' is about a man named ricky bobby -lrb- will ferrell -rrb- who as a boy always dreamed of being a race car driver and living life in the fast lane . &lt; xxrep 5 s &gt; so one day , ricky bobby got the chance of a lifetime as he was able to race in a nascar tournament .</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <td>xxbos what is with hollywood and the concept of love in the mitts of great disasters ? &lt; xxrep 5 s &gt; there can be no greater example of this obsession than the highest grossing film of all time , titanic . &lt; xxrep 5 s &gt; though the oscar darling can be blamed for the most recent trend , it is not the first to start this . &lt;</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <td>xxbos director walter stuck faithfully to ernesto guevara and alberto granado 's book recounting their 1952 adventure traveling through thousands of miles of south america , much of their adventure taking them through magnificent wilderness and provincial small towns . &lt; xxrep 5 s &gt; guevara -lrb- gael garcia bernal -rrb- was about a semester away from receiving his medical degree . &lt; xxrep 5 s &gt; his jovial companion</td>
#       <td>7</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit_one_cycle(1, 1e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.791870</td>
#       <td>1.714865</td>
#       <td>0.316141</td>
#       <td>08:02</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Save intermediate model to enable resuming training from stages
learn.save('stage-1-model.pkl')

# %%
learn.load('stage-1-model.pkl')
# Out:
# RNNLearner(data=TextClasDataBunch;
#
# Train: LabelList (16839 items)
# x: TextList
# xxbos sometimes popular opinion really sucks about a film elevating a rotten movie to cult status and if you do n't like it then you obviously do n't get it . < xxrep 5 s > this movie is one of them . < xxrep 5 s > the much discussed camera moves did not make me sick , but the whiny idiotic characters did . < xxrep 5 s > the suspense was minimal . < xxrep 5 s > i do n't care if it was really low budget . < xxrep 5 s > i ' m not going to grade a film on degree of difficulty . < xxrep 5 s > i ' m sure that `` titanic '' was a very tough experience for the production crew . < xxrep 5 s > i do n't care ! < xxrep 5 s > it was a great movie because it had a great story and great characters and was really well put together . < xxrep 5 s > this movie did n't have any of those things . < xxrep 5 s > it telegraphed the last shot in the first 15 minutes . < xxrep 5 s > this is one of those rare films that made me angry that i wasted my time with it .,xxbos this is an amazing piece of work and it probably tops `` the insider '' , `` the sixth sense '' ,
ie makers knew when to cut the action . < xxrep 5 s > however -- like iron man -- the acting is way above average for this sort of escapism , but , come to think of it , all 3 xxunk & x - men + batman begins -lrb- & returns -rrb- also featured really fine & often great acting . < xxrep 5 s > and this hulk could ' ve used more of it . < xxrep 5 s > norton is 1 of the top 5 actors currently working . < xxrep 5 s > there are moments in this movie when his talent really pays off and they are all too brief . < xxrep 5 s > william hurt makes a fine foe . < xxrep 5 s > and , so help me movie gods , liv tyler gives a memorable performance although she is mostly stuck saying the name `` bruce '' . < xxrep 5 s > overall this movie rocks . < xxrep 5 s > and i thought all movies released xxunk july 18th were just until the dark knight arrives . < xxrep 5 s > thank you tony stark , indy & bruce banner for proving me wrong .,xxbos it is no surprise that gary ross -- the writer of big and dave -- once again brings a very smart comedy to the big screen , but what is surprising is the level of directorial xxunk that he brings to a very complex undertaking . < xxrep 5 s > pleasantville is a wonderful laugh - out - loud satire that deals with issues such as racism , fascism , artistic freedom , individuality , sexual mores , 90 's amorality , group control and some other things i probably missed . < xxrep 5 s > but ross wraps his messages in ambiguity and , most importantly , entertainment . < xxrep 5 s > any movie that uses don knotts effectively has really got its wits about it . < xxrep 5 s > the performances from every single actor -- including extras -- are kubrickian in their perfection and often hilarious . < xxrep 5 s > tobey maguire , reese witherspoon and joan allen are standouts in this standout cast . < xxrep 5 s > maguire is very good at showing the thought processes going on inside his head behind his eyes . < xxrep 5 s > witherspoon 's vixen is devious without being mean . < xxrep 5 s > and allen , like she did in face / off , brings a heart and soul that is key to the amazing things going on around her and to her . < xxrep 5 s > this movie tops there 's something about mary on the laugh meter and furthermore the way allen 's scene in the bathtub pays off is as outrageous as ... mary 's hair gel scene . < xxrep 5 s > the first hour of this movie is as funny as anything i ' ve ever seen . < xxrep 5 s > i have n't even mentioned the `` look '' of this film yet . < xxrep 5 s > it is fantastic . < xxrep 5 s > the seamless blend of color and black - and - white ceases to become an issue very early on . < xxrep 5 s > you accept this parallel universe for what it is and that is the highest compliment you can pay to the effects crew . < xxrep 5 s > fortunately ross does n't miss any opportunity to use it for laughs and social comment . < xxrep 5 s > some people have criticized the movie for waffling on the themes it speaks to , but i feel that any ambiguity that ross built into the script was simply meant to avoid any preaching and let the audience make up its own mind about what the movie means . < xxrep 5 s > my only real criticism of pleasantville is that it may be a bit too ambitious for its own good , but i 'd much rather have a movie that tries ...
# y: EmptyLabelList
# ,,,,
# Path: data, model=SequentialRNN(
#   (0): MultiBatchEncoder(
#     (module): AWD_LSTM(
#       (encoder): Embedding(43863, 400, padding_idx=1)
#       (encoder_dp): EmbeddingDropout(
#         (emb): Embedding(43863, 400, padding_idx=1)
#       )
#       (rnns): ModuleList(
#         (0): WeightDropout(
#           (module): LSTM(400, 1150, batch_first=True)
#         )
#         (1): WeightDropout(
#           (module): LSTM(1150, 1150, batch_first=True)
#         )
#         (2): WeightDropout(
#           (module): LSTM(1150, 400, batch_first=True)
#         )
#       )
#       (input_dp): RNNDropout()
#       (hidden_dps): ModuleList(
#         (0): RNNDropout()
#         (1): RNNDropout()
#         (2): RNNDropout()
#       )
#     )
#   )
#   (1): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1)
#       (6): Linear(in_features=50, out_features=10, bias=True)
#     )
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of CrossEntropyLoss(), metrics=[<function accuracy at 0x7f536c2e99d8>], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('data'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True)], callbacks=[...], layer_groups=[Sequential(
#   (0): Embedding(43863, 400, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(43863, 400, padding_idx=1)
#   )
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(400, 1150, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1150, 1150, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1150, 400, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1)
#       (6): Linear(in_features=50, out_features=10, bias=True)
#     )
#   )
# )], add_time=True)
# alpha: 2.0
# beta: 1.0], layer_groups=[Sequential(
#   (0): Embedding(43863, 400, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(43863, 400, padding_idx=1)
#   )
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(400, 1150, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1150, 1150, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1150, 400, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1)
#       (6): Linear(in_features=50, out_features=10, bias=True)
#     )
#   )
# )], add_time=True)

# %% [markdown]
# ### Fine-tuning

# %%
learn.freeze_to(-2)
# Slice up the learning rates to apply different rates to different layers of the network - the deeper the larger.
learn.fit_one_cycle(1, slice(5e-3/2., 5e-3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.612746</td>
#       <td>1.554340</td>
#       <td>0.380611</td>
#       <td>09:15</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2-model.pkl')

# %%
learn.load('stage-2-model.pkl')
# Out:
# RNNLearner(data=TextClasDataBunch;
#
# Train: LabelList
# y: CategoryList
# 6,10,9,10,10
# Path: data;
#
# Test: LabelList (2278 items)
# x: TextList
# xxbos edward norton is right & wrong . < xxrep 5 s > this movie could have used more of him in it -lrb- when the dvd comes out i hope they include `` his cut '' if it exist -rrb- , but he is wrong for not promoting this movie . < xxrep 5 s > this re - boot is a blast to watch . < xxrep 5 s > i actually liked much of ang lee 's version but only in fits & starts . < xxrep 5 s > this hulk is a much smoother machine that never drags . < xxrep 5 s > the fx are spectacular & sometimes inspired -- every part of the production is great . < xxrep 5 s > the battle scenes are ferocious . < xxrep 5 s > i never tired of watching mean green do his thing , but i guess that s the point . < xxrep 5 s > the movie makers knew when to cut the action . < xxrep 5 s > however -- like iron man -- the acting is way above average for this sort of escapism , but , come to think of it , all 3 xxunk & x - men + batman begins -lrb- & returns -rrb- also featured really fine & often great acting . < xxrep 5 s > and this hulk could ' ve used more of it . < xxrep 5 s > norton is 1 of the top 5 actors currently working . < xxrep 5 s > there are moments in this movie when his talent really pays off and they are all too brief . < xxrep 5 s > william hurt makes a fine foe . < xxrep 5 s > and , so help me movie gods , liv tyler gives a memorable performance although she is mostly stuck saying the name `` bruce '' . < xxrep 5 s > overall this movie rocks . < xxrep 5 s > and i thought all movies released xxunk july 18th were just until the dark knight arrives . < xxrep 5 s > thank you tony stark , indy & bruce banner for proving me wrong .,xxbos it is no surprise that gary ross -- the writer of big and dave -- once again brings a very smart comedy to the big screen , but what is surprising is the level of directorial xxunk that he brings to a very complex undertaking . < xxrep 5 s > pleasantville is a wonderful laugh - out - loud satire that deals with issues such as racism , fascism , artistic freedom , individuality , sexual mores , 90 's amorality , group control and some other things i probably missed . < xxrep 5 s > but ross wraps his messages in ambiguity and , most importantly , entertainment . < xxrep 5 s > any movie that uses don knotts effectively has really got its wits about it . < xxrep 5 s > the performances from every single actor -- including extras -- are kubrickian in their perfection and often hilarious . < xxrep 5 s > tobey maguire , reese witherspoon and joan allen are standouts in this standout cast . < xxrep 5 s > maguire is very good at showing the thought processes going on inside his head behind his eyes . < xxrep 5 s > witherspoon 's vixen is devious without being mean . < xxrep 5 s > and allen , like she did in face / off , brings a heart and soul that is key to the amazing things going on around her and to her . < xxrep 5 s > this movie tops there 's something about mary on the laugh meter and furthermore the way allen 's scene in the bathtub pays off is as outrageous as ... mary 's hair gel scene . < xxrep 5 s > the first hour of this movie is as funny as anything i ' ve ever seen . < xxrep 5 s > i have n't even mentioned the `` look '' of this film yet . < xxrep 5 s > it is fantastic . < xxrep 5 s > the seamless blend of color and black - and - white ceases to become an issue very early on . < xxrep 5 s > you accept this parallel universe for what it is and that is the highest compliment you can pay to the effects crew . < xxrep 5 s > fortunately ross does n't miss any opportunity to use it for laughs and social comment . < xxrep 5 s > some people have criticized the movie for waffling on the themes it speaks to , but i feel that any ambiguity that ross built into the script was simply meant to avoid any preaching and let the audience make up its own mind about what the movie means . < xxrep 5 s > my only real criticism of pleasantville is that it may be a bit too ambitious for its own good , but i 'd much rather have a movie that tries ...
# y: EmptyLabelList
# ,,,,
# Path: data, model=SequentialRNN(
#   (0): MultiBatchEncoder(
#     (module): AWD_LSTM(
#       (encoder): Embedding(43863, 400, padding_idx=1)
#       (encoder_dp): EmbeddingDropout(
#         (emb): Embedding(43863, 400, padding_idx=1)
#       )
#       (rnns): ModuleList(
#         (0): WeightDropout(
#           (module): LSTM(400, 1150, batch_first=True)
#         )
#         (1): WeightDropout(
#           (module): LSTM(1150, 1150, batch_first=True)
#         )
#         (2): WeightDropout(
#           (module): LSTM(1150, 400, batch_first=True)
#         )
#       )
#       (input_dp): RNNDropout()
#       (hidden_dps): ModuleList(
#         (0): RNNDropout()
#         (1): RNNDropout()
#         (2): RNNDropout()
#       )
#     )
#   )
#   (1): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1)
#       (6): Linear(in_features=50, out_features=10, bias=True)
#     )
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of CrossEntropyLoss(), metrics=[<function accuracy at 0x7f536c2e99d8>], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('data'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True)], callbacks=[...], layer_groups=[Sequential(
#   (0): Embedding(43863, 400, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(43863, 400, padding_idx=1)
#   )
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(400, 1150, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1150, 1150, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1150, 400, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1)
#       (6): Linear(in_features=50, out_features=10, bias=True)
#     )
#   )
# )], add_time=True)
# alpha: 2.0
# beta: 1.0], layer_groups=[Sequential(
#   (0): Embedding(43863, 400, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(43863, 400, padding_idx=1)
#   )
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(400, 1150, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1150, 1150, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1150, 400, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1)
#       (6): Linear(in_features=50, out_features=10, bias=True)
#     )
#   )
# )], add_time=True)

# %%
learn.unfreeze()
learn.fit_one_cycle(1, slice(2e-3/100, 2e-3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.518762</td>
#       <td>1.490982</td>
#       <td>0.403534</td>
#       <td>18:04</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Save our final model
learn.save('final-model.pkl') # 487.053M

# %%
learn.load('final-model.pkl')
# Out:
# RNNLearner(data=TextClasDataBunch;
#
# Train: LabelList (16839 items)
# x: TextList
# xxbos sometimes popular opinion really sucks about a film elevating a rotten movie to cult status and if you do n't like it then you obviously do n't get it . < xxrep 5 s > this movie is one of them . < xxrep 5 s > the much discussed camera moves did not make me sick , but the whiny idiotic characters did . < xxrep 5 s > the suspense was minimal . < xxrep 5 s > i do n't care if it was really low budget . < xxrep 5 s > i ' m not going to grade a film on degree of difficulty . < xxrep 5 s > i ' m sure that `` titanic '' was a very tough experience for the production crew . < xxrep 5 s > i do n't care ! < xxrep 5 s > it was a great movie because it had a great story and great characters and was really well put together . < xxrep 5 s > this movie did n't have any of those things . < xxrep 5 s > it telegraphed the last shot in the first 15 minutes . < xxrep 5 s > this is one of those rare films that made me angry that i wasted my time with it .,xxbos this is an amazing piece of work and it probably tops `` the insider '' , `` the sixth sense '' , `` edtv '' and `` bringing out the dead '' as my favorite film of the year . < xxrep 5 s > alan ball 's screenplay is one the modern wonders of the world and sam mendes 's direction matches it -lrb- i can see why he bested michael mann as the l.a . film critics director of the year -rrb- . < xxrep 5 s > where did these guys come from ? < xxrep 5 s > this story of an american family and the tiny slice of the world they live in is xxunk before us with the precision and fascination of a geneticist unravelling a strand of dna through an xxunk microscope . < xxrep 5 s > this is not to suggest that the film is cold -lrb- far from it -rrb- . < xxrep 5 s > it just felt like i was watching the characters lives from beneath their skins . < xxrep 5 s > rarely have i felt like i knew an entire cast so well . < xxrep 5 s > this will be a hard movie to reward at oscar time because every single performance hit exactly the right key -lrb- `` l.a . confidential '' had the same problem -rrb- , but obviously kevin spacey and annette benning should lead actor noms . < xxrep 5 s > spacey has played laconic many times before -lrb- i ca n't think of a film where he has n't been this way before -rrb- , but not with the dry wit and comic timing he displays here . < xxrep 5 s > even when he blows up it is dry . < xxrep 5 s > benning has her best role since `` the grifters '' and makes the most it . < xxrep 5 s > she is a stepford wife with real ambition . < xxrep 5 s > they are a married couple who long ago gave up on the american dream but are too comfortable to give up the amercian facade and this is ball 's key contempt . < xxrep 5 s > it is a very unique view . < xxrep 5 s > while the adults know that they are screwed up the kids still fight to have hope . < xxrep 5 s > it is their rebellion . < xxrep 5 s > thora xxunk is outstanding as the lone child of spacey and benning who is getting killed by her parents ' cynicism . < xxrep 5 s > the most frightening performance is given by wes bentley as the next door neighbor kid who is constantly peeping and taping other people 's lives , but also finding beauty amid the ugliness and chaos in some of the film 's most moving scenes -lrb- a lot people will not get the significance and meaning of the paper bag , but those who do understand the film completely -- i thought is was awesome -rrb- . < xxrep 5 s > i think he is acting as the xxunk . < xxrep 5 s > finally mena suvari is a revelation as the smart - ass and all - knowing teenage friend who reveals a heartbreaking vulnerability . < xxrep 5 s > this film is very dark but like `` bringing out the dead '' there is a redemptive quality leaves you with hope at the end . < xxrep 5 s > i was floored by this . < xxrep 5 s > it is also a very funny film . < xxrep 5 s > american beauty may be the best film of a very good year .,xxbos this movie does not belong in a cinema . < xxrep 5 s > it belongs in a museum of modern art  ...
# y: CategoryList
# 1,10,5,10,10
# Path: data;
#
# Valid: LabelList (2094 items)
# x: TextList
# xxbos i ' m a huge fan of michael mann -lrb- i even liked the keep a lot -rrb- . < xxrep 5 s > nobody , even martin scorsese , does lawmen and the lawless better . < xxrep 5 s > thief , heat and collateral are all classics -lrb- heat is as good as the 1st 2 godfathers -rrb- . < xxrep 5 s > cut to the chase . < xxrep 5 s > miami vice is a disappointment . < xxrep 5 s > i ' m glad it xxunk from the -lrb- excellent -rrb- tv show . < xxrep 5 s > as a feature film it is flat and not involving . < xxrep 5 s > colin farrell can not hold the screen as a leading man . < xxrep 5 s > jamie foxx is handcuffed in a thankless role . < xxrep 5 s > the villains are dull . < xxrep 5 s > the action set pieces are few and seem like limp ripoffs of his other films . < xxrep 5 s > there is no synergy here . < xxrep 5 s > michael mann is all synergy . < xxrep 5 s > the music is uninspired . < xxrep 5 s > the editing is as confusing as the plot . < xxrep 5 s > dion beebe 's groundbreaking high def work in collateral does n't work very well for this film . < xxrep 5 s > there is not a single memorable moment in this film and coming from mann that is a shock . < xxrep 5 s > i ' m rating this film against mann 's other films because i ca n't do so otherwise -lrb- like spielberg , cameron , howard , nolan , greengrass , eastwood and any other a - lister -rrb- . < xxrep 5 s > so why do i give it a 6 / 10 ?,xxbos this film is unavoidably being compared to director alan j. pakula 's `` all the president 's men '' and for good reason , because michael mann 's new film is every bit as good . < xxrep 5 s > -lrb- anybody is the tv news biz - like me - knows that newspaper and tv news are very different animals . < xxrep 5 s > -rrb- `` the insider '' is a very mature film . < xxrep 5 s > it takes its sweet time letting the events unfold . < xxrep 5 s > however mann and his team use very cinematic trick in the book to hold our attention and the editing is impeccable . < xxrep 5 s > but first and foremost the film features 2 virtuoso performances : one by a master we ' ve grown accustomed to and one by a guy who may have joined his league . < xxrep 5 s > of course i ' m talking about al pacino and russell crowe . < xxrep 5 s > pacino adds another mammoth blast in his hall of fame collection of home run performances . < xxrep 5 s > his portrayal of 60 minutes producer gives him a lot of room to use all his skills as an actor and he never ever looks like an actor acting . < xxrep 5 s > he vents anger and frustration better than any actor i ' ve ever seen and he is given the chance to do so here . < xxrep 5 s > now on to the `` new '' guy . < xxrep 5 s > anybody who has seen russell crowe before -lrb- especially in his oscar - worthy effort in `` l.a . confidential '' -rrb- is not surprised that he can more than hold his own against pacino , but then again acting is not a sporting event and there is room for a lot of winners in a movie like this . < xxrep 5 s > crowe 's role as `` the guy '' who blows the whistle on the tobacco industry is a fascinating study of a man imploding . < xxrep 5 s > not since pacino 's work in `` the godfather ii '' have i ' ve seen it done so well . < xxrep 5 s > like every other thing mann has done the supporting actors are great too , but the standout here is christopher plummer 's mike wallace who has to reluctantly sell out to the corporate bottom line . < xxrep 5 s > the story about a guy who wants to go public about a major public health crime but is abandoned by a major network is complex and difficult stuff , but mann and co - scripter eric roth do a magnificent job at keeping it clear and interesting . < xxrep 5 s > it is riveting and important entertainment . < xxrep 5 s > like the phrase `` tv journalism '' , `` important entertainment '' may seem like a contradiction of terms , but not with this movie which is one the best films of the year .,xxbos we start all of our reviews with the following information . < xxrep 5 s > my  ...
# y: CategoryList
# 6,10,9,10,10
# Path: data;
#
# Test: LabelList (2278 items)
# x: TextList
# xxbos edward norton is right & wrong . < xxrep 5 s > this movie could have used more of him in it -lrb- when the dvd comes out i hope they include `` his cut '' if it exist -rrb- , but he is wrong for not promoting this movie . < xxrep 5 s > this re - boot is a blast to watch . < xxrep 5 s > i actually liked much of ang lee 's version but only in fits & starts . < xxrep 5 s > this hulk is a much smoother machine that never drags . < xxrep 5 s > the fx are spectacular & sometimes inspired -- every part of the production is great . < xxrep 5 s > the battle scenes are ferocious . < xxrep 5 s > i never tired of watching mean green do his thing , but i guess that s the point . < xxrep 5 s > the movie makers knew when to cut the action . < xxrep 5 s > however -- like iron man -- the acting is way above average for this sort of escapism , but , come to think of it , all 3 xxunk & x - men + batman begins -lrb- & returns -rrb- also featured really fine & often great acting . < xxrep 5 s > and this hulk could ' ve used more of it . < xxrep 5 s > norton is 1 of the top 5 actors currently working . < xxrep 5 s > there are moments in this movie when his talent really pays off and they are all too brief . < xxrep 5 s > william hurt makes a fine foe . < xxrep 5 s > and , so help me movie gods , liv tyler gives a memorable performance although she is mostly stuck saying the name `` bruce '' . < xxrep 5 s > overall this movie rocks . < xxrep 5 s > and i thought all movies released xxunk july 18th were just until the dark knight arrives . < xxrep 5 s > thank you tony stark , indy & bruce banner for proving me wrong .,xxbos it is no surprise that gary ross -- the writer of big and dave -- once again brings a very smart comedy to the big screen , but what is surprising is the level of directorial xxunk that he brings to a very complex undertaking . < xxrep 5 s > pleasantville is a wonderful laugh - out - loud satire that deals with issues such as racism , fascism , artistic freedom , individuality , sexual mores , 90 's amorality , group control and some other things i probably missed . < xxrep 5 s > but ross wraps his messages in ambiguity and , most importantly , entertainment . < xxrep 5 s > any movie that uses don knotts effectively has really got its wits about it . < xxrep 5 s > the performances from every single actor -- including extras -- are kubrickian in their perfection and often hilarious . < xxrep 5 s > tobey maguire , reese witherspoon and joan allen are standouts in this standout cast . < xxrep 5 s > maguire is very good at showing the thought processes going on inside his head behind his eyes . < xxrep 5 s > witherspoon 's vixen is devious without being mean . < xxrep 5 s > and allen , like she did in face / off , brings a heart and soul that is key to the amazing things going on around her and to her . < xxrep 5 s > this movie tops there 's something about mary on the laugh meter and furthermore the way allen 's scene in the bathtub pays off is as outrageous as ... mary 's hair gel scene . < xxrep 5 s > the first hour of this movie is as funny as anything i ' ve ever seen . < xxrep 5 s > i have n't even mentioned the `` look '' of this film yet . < xxrep 5 s > it is fantastic . < xxrep 5 s > the seamless blend of color and black - and - white ceases to become an issue very early on . < xxrep 5 s > you accept this parallel universe for what it is and that is the highest compliment you can pay to the effects crew . < xxrep 5 s > fortunately ross does n't miss any opportunity to use it for laughs and social comment . < xxrep 5 s > some people have criticized the movie for waffling on the themes it speaks to , but i feel that any ambiguity that ross built into the script was simply meant to avoid any preaching and let the audience make up its own mind about what the movie means . < xxrep 5 s > my only real criticism of pleasantville is that it may be a bit too ambitious for its own good , but i 'd much rather have a movie that tries ...
# y: EmptyLabelList
# ,,,,
# Path: data, model=SequentialRNN(
#   (0): MultiBatchEncoder(
#     (module): AWD_LSTM(
#       (encoder): Embedding(43863, 400, padding_idx=1)
#       (encoder_dp): EmbeddingDropout(
#         (emb): Embedding(43863, 400, padding_idx=1)
#       )
#       (rnns): ModuleList(
#         (0): WeightDropout(
#           (module): LSTM(400, 1150, batch_first=True)
#         )
#         (1): WeightDropout(
#           (module): LSTM(1150, 1150, batch_first=True)
#         )
#         (2): WeightDropout(
#           (module): LSTM(1150, 400, batch_first=True)
#         )
#       )
#       (input_dp): RNNDropout()
#       (hidden_dps): ModuleList(
#         (0): RNNDropout()
#         (1): RNNDropout()
#         (2): RNNDropout()
#       )
#     )
#   )
#   (1): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1)
#       (6): Linear(in_features=50, out_features=10, bias=True)
#     )
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of CrossEntropyLoss(), metrics=[<function accuracy at 0x000001BA011ADA60>], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=WindowsPath('data'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True)], callbacks=[RNNTrainer
# learn: ...
# alpha: 2.0
# beta: 1.0], layer_groups=[Sequential(
#   (0): Embedding(43863, 400, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(43863, 400, padding_idx=1)
#   )
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(400, 1150, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1150, 1150, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1150, 400, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1)
#       (6): Linear(in_features=50, out_features=10, bias=True)
#     )
#   )
# )], add_time=True)

# %%
learn.predict("This was a okay movie!")
# Out:
# D:\Dev\Tools\Anaconda\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# (Category 5,
#  tensor(4),
#  tensor([0.1114, 0.0561, 0.1459, 0.0720, 0.2170, 0.1737, 0.1432, 0.0546, 0.0199,
#          0.0063]))

# %% [markdown]
# ## Predict Helper Function

# %%
def predict(text):
    return learn.predict(text)[1].item() + 1

# %%
predict("This is a find so good movie amazing best top of the list!")
# Out:
# D:\Dev\Tools\Anaconda\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# 10

# %% [markdown]
# ## Calculate RMSE on Validation Set

# %%
import math
import warnings
warnings.filterwarnings("ignore")

mse_loss = 0
vali_len = len(validation_df.index)
for i in range(vali_len):
    line = validation_df.iloc[i]
    text = line['review_content']
    rating = line['rating']
    pred = predict(text)
    mse_loss += (rating - pred) ** 2
    
    if i % 10 == 0:
        print("{} finished".format(i))

rmse_loss = math.sqrt(mse_loss / vali_len)
# Out:
# 0 finished
# 10 finished
# 20 finished
# 30 finished
# 40 finished
# 50 finished
# 60 finished
# 70 finished
# 80 finished
# 90 finished
# 100 finished
# 110 finished
# 120 finished
# 130 finished
# 140 finished
# 150 finished
# 160 finished
# 170 finished
# 180 finished
# 190 finished
# 200 finished
# 210 finished
# 220 finished
# 230 finished
# 240 finished
# 250 finished
# 260 finished
# 270 finished
# 280 finished
# 290 finished
# 300 finished
# 310 finished
# 320 finished
# 330 finished
# 340 finished
# 350 finished
# 360 finished
# 370 finished
# 380 finished
# 390 finished
# 400 finished
# 410 finished
# 420 finished
# 430 finished
# 440 finished
# 450 finished
# 460 finished
# 470 finished
# 480 finished
# 490 finished
# 500 finished
# 510 finished
# 520 finished
# 530 finished
# 540 finished
# 550 finished
# 560 finished
# 570 finished
# 580 finished
# 590 finished
# 600 finished
# 610 finished
# 620 finished
# 630 finished
# 640 finished
# 650 finished
# 660 finished
# 670 finished
# 680 finished
# 690 finished
# 700 finished
# 710 finished
# 720 finished
# 730 finished
# 740 finished
# 750 finished
# 760 finished
# 770 finished
# 780 finished
# 790 finished
# 800 finished
# 810 finished
# 820 finished
# 830 finished
# 840 finished
# 850 finished
# 860 finished
# 870 finished
# 880 finished
# 890 finished
# 900 finished
# 910 finished
# 920 finished
# 930 finished
# 940 finished
# 950 finished
# 960 finished
# 970 finished
# 980 finished
# 990 finished
# 1000 finished
# 1010 finished
# 1020 finished
# 1030 finished
# 1040 finished
# 1050 finished
# 1060 finished
# 1070 finished
# 1080 finished
# 1090 finished
# 1100 finished
# 1110 finished
# 1120 finished
# 1130 finished
# 1140 finished
# 1150 finished
# 1160 finished
# 1170 finished
# 1180 finished
# 1190 finished
# 1200 finished
# 1210 finished
# 1220 finished
# 1230 finished
# 1240 finished
# 1250 finished
# 1260 finished
# 1270 finished
# 1280 finished
# 1290 finished
# 1300 finished
# 1310 finished
# 1320 finished
# 1330 finished
# 1340 finished
# 1350 finished
# 1360 finished
# 1370 finished
# 1380 finished
# 1390 finished
# 1400 finished
# 1410 finished
# 1420 finished
# 1430 finished
# 1440 finished
# 1450 finished
# 1460 finished
# 1470 finished
# 1480 finished
# 1490 finished
# 1500 finished
# 1510 finished
# 1520 finished
# 1530 finished
# 1540 finished
# 1550 finished
# 1560 finished
# 1570 finished
# 1580 finished
# 1590 finished
# 1600 finished
# 1610 finished
# 1620 finished
# 1630 finished
# 1640 finished
# 1650 finished
# 1660 finished
# 1670 finished
# 1680 finished
# 1690 finished
# 1700 finished
# 1710 finished
# 1720 finished
# 1730 finished
# 1740 finished
# 1750 finished
# 1760 finished
# 1770 finished
# 1780 finished
# 1790 finished
# 1800 finished
# 1810 finished
# 1820 finished
# 1830 finished
# 1840 finished
# 1850 finished
# 1860 finished
# 1870 finished
# 1880 finished
# 1890 finished
# 1900 finished
# 1910 finished
# 1920 finished
# 1930 finished
# 1940 finished
# 1950 finished
# 1960 finished
# 1970 finished
# 1980 finished
# 1990 finished
# 2000 finished
# 2010 finished
# 2020 finished
# 2030 finished
# 2040 finished
# 2050 finished
# 2060 finished
# 2070 finished
# 2080 finished
# 2090 finished

# %% [markdown]
# **RMSE:**

# %%
rmse_loss
# Out:
# 1.5641335777652257

# %% [markdown]
# ## Make Predictions on Test Set

# %%
ratings = []
for line in test_df['review_content']:
    ratings.append(predict(line))

# %%
output_data = {'review_content': test_df['review_content'], 'rating': ratings}

# %%
# Save result
output_df = pd.DataFrame(output_data)
output_df.to_csv('senti_output.ss', sep='\t')

# %% [markdown]
# ## Conclusion
#
# **Sizes:**
#
# Language Model Size:      191.32M
#
# Classifier Model Size:    487.05M
#
# Total Size:               678.37M
#
# **Loss:**
#
# RMSE:          1.5641335777652257
#
# **Test Set Output:**
#
# File:             senti_output.ss
#
# **Comment:**
#
# Apparently, this looks way better than "Plan A". I trained the language model using AWD_LSTM, and I trained the classifier using also AWD_LSTM, which makes those two models big yet powerful. With the size of almost 20 times as "Plan A", I managed to get the loss down to 68% of "Plan A".
#
# Judging by the look of testset predictions, I think the outcome is pretty impressive. Most predicted ratings won't be found absurd at all, instead, most of them are reasonable and hard to tell whether they are labels or predictions.
